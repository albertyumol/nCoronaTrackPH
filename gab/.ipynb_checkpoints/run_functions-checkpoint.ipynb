# %%
from article_parser import get_covid_counts

# %%
    df = df[df['counts'] != '1300\n\nConfirmed']
    df = df[df['Loc'] != '']

# %%
df2.sort_values('date')
# Out:
#           date       Loc    min_  min_confirmed  min_suspected    max_  \
# 0   2020-01-21  batangas     NaN            NaN            NaN     NaN
# 12  2020-01-23     aklan     NaN            NaN            3.0     NaN
# 1   2020-01-23      cebu     NaN            NaN            NaN     NaN
# 2   2020-01-24      cebu     NaN            NaN           14.0     NaN
# 18  2020-01-24    iloilo     NaN            NaN          881.0     NaN
# 13  2020-01-25     aklan     NaN            NaN           80.0     NaN
# 3   2020-01-25      cebu     NaN            NaN           14.0     NaN
# 22  2020-01-27  camiguin     NaN            NaN          106.0     NaN
# 4   2020-01-27      cebu     4.0            NaN           14.0    11.0
# 5   2020-01-28      cebu     4.0            NaN           14.0    24.0
# 14  2020-01-28     aklan     NaN            NaN           11.0     NaN
# 6   2020-01-30      cebu     4.0            1.0           14.0    24.0
# ...
